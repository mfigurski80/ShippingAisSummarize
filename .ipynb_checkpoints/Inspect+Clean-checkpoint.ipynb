# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("MONTHLY_AIS.csv", parse_dates=['date'])
df = df.groupby('date').last()
# df.drop(pd.Timestamp('2015-05-01')).resample('M').mean().fillna(0)
df = df.resample('M').mean().fillna(0)
df
# Out:
#             nShips  totalKmCovered  avgDaysPresent  avgDaysStationary  \
# date
# 2015-01-31      15        12140.81            9.00               3.87
# 2015-02-28      16         7089.60            7.50               4.56
# 2015-03-31      20        11635.69            8.70               4.70
# 2015-04-30      16        10434.40            7.06               3.38
# 2015-05-31      14        13470.87            9.21               2.93
# ...            ...             ...             ...                ...
# 2021-08-31     158       230472.08            9.70               5.56
# 2021-09-30     180       368191.23           10.04               4.82
# 2021-10-31     187       310669.30           10.52               4.56
# 2021-11-30     157       384693.95           10.41               3.85
# 2021-12-31     142       206362.94            8.35               3.37
#
#             avgProportionOfStationaryDays  numDaysInMonth  totalShipArea  \
# date
# 2015-01-31                           0.33              31      162907.00
# 2015-02-28                           0.37              28      129006.00
# 2015-03-31                           0.53              31      199669.00
# 2015-04-30                           0.39              30      157517.00
# 2015-05-31                           0.40              31      158058.00
# ...                                   ...             ...            ...
# 2021-08-31                           0.46              31     1666971.04
# 2021-09-30                           0.37              30     1797230.52
# 2021-10-31                           0.34              31     1918129.72
# 2021-11-30                           0.32              30     1660381.60
# 2021-12-31                           0.34              31     1449368.88
#
#             totalShipAreaPresent  totalShipAreaStationary  nShipsEntered  \
# date
# 2015-01-31              43192.26                 22351.45              0
# 2015-02-28              42846.29                 30003.14              0
# 2015-03-31              52520.13                 32783.77              0
# 2015-04-30              28617.40                 13986.13              0
# 2015-05-31              47628.58                 18223.61              0
# ...                          ...                      ...            ...
# 2021-08-31             557718.65                332519.48              0
# 2021-09-30             621517.97                314256.12              0
# 2021-10-31             693487.89                320415.81              0
# 2021-11-30             598837.10                220422.05              0
# 2021-12-31             404233.61                177565.73              0
#
#             nShipsExited
# date
# 2015-01-31             0
# 2015-02-28             0
# 2015-03-31             0
# 2015-04-30             0
# 2015-05-31             0
# ...                  ...
# 2021-08-31             0
# 2021-09-30             0
# 2021-10-31             0
# 2021-11-30             0
# 2021-12-31             0
#
# [84 rows x 11 columns]

# %%
(df[['nShips']]).plot()
# plt.plot(df['date'], df['totalShipAreaPresent'])

# %%
safe = df.index >= pd.Timestamp('2018-01')
# df[safe]
df[safe][['nShips']].plot()

# %%
df.to_csv('MONTHLY_AIS_cleaned.csv', date_format='%Y-%m')
